# %% [markdown]
# # Model

# %% [markdown]
# In this notebook, clustering is not applied before training.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/boreholes_uscs_sptn.csv')
df
# Out:
#        Borehole ID   Latitude   Longitude  Elevation (ft)  In-situ Test #  \
# 0               21  47.568436 -122.407480           77.30               1
# 1               21  47.568436 -122.407480           77.30               2
# 2               21  47.568436 -122.407480           77.30               3
# 3               21  47.568436 -122.407480           77.30               4
# 4               21  47.568436 -122.407480           77.30               5
# ...            ...        ...         ...             ...             ...
# 19711       153205  47.437412 -122.242456           23.75               9
# 19712       153205  47.437412 -122.242456           23.75              10
# 19713       153205  47.437412 -122.242456           23.75              11
# 19714       153205  47.437412 -122.242456           23.75              12
# 19715       153205  47.437412 -122.242456           23.75              13
#
#        Test Elevation (ft)  SPTN  Layer #  Layer Top Elevation (ft)  \
# 0                    77.30   3.0        1                     77.30
# 1                    75.80  12.0        2                     75.80
# 2                    74.30   8.0        2                     75.80
# 3                    73.30   7.0        2                     75.80
# 4                    71.80   7.0        2                     75.80
# ...                    ...   ...      ...                       ...
# 19711                -8.75  44.0        6                     -3.25
# 19712               -13.75  23.0        6                     -3.25
# 19713               -18.75  43.0        6                     -3.25
# 19714               -23.75  27.0        6                     -3.25
# 19715               -28.75  19.0        6                     -3.25
#
#        Layer Bottom Elevation (ft)  \
# 0                            75.80
# 1                            70.30
# 2                            70.30
# 3                            70.30
# 4                            70.30
# ...                            ...
# 19711                       -30.25
# 19712                       -30.25
# 19713                       -30.25
# 19714                       -30.25
# 19715                       -30.25
#
#                                         Soil Description   Lithology  USCS  \
# 0      Grayish brown, dry, very loose, well graded sa...        Fill  Fill
# 1      Clay, medium gray, stiff, slightly moist, with...        Clay    CH
# 2      Clay, medium gray, stiff, slightly moist, with...        Clay    CH
# 3      Clay, medium gray, stiff, slightly moist, with...        Clay    CH
# 4      Clay, medium gray, stiff, slightly moist, with...        Clay    CH
# ...                                                  ...         ...   ...
# 19711  Dark gray silty fine to medium sand, loose bec...  Silty sand    SM
# 19712  Dark gray silty fine to medium sand, loose bec...  Silty sand    SM
# 19713  Dark gray silty fine to medium sand, loose bec...  Silty sand    SM
# 19714  Dark gray silty fine to medium sand, loose bec...  Silty sand    SM
# 19715  Dark gray silty fine to medium sand, loose bec...  Silty sand    SM
#
#       Density / Consistency
# 0                       NaN
# 1                     Stiff
# 2                    Medium
# 3                    Medium
# 4                    Medium
# ...                     ...
# 19711                 Dense
# 19712                Medium
# 19713                 Dense
# 19714                 Dense
# 19715                Medium
#
# [19716 rows x 14 columns]

# %%
table_uscs = pd.read_csv('../data/file_2_reUSCS_sampling_with_elevation.csv')
table_uscs
# Out:
#         Borehole ID  Document ID   Latitude   Longitude  Elevation  \
# 0                 1          342  47.574251 -122.407051     148.80
# 1                 1          342  47.574251 -122.407051     148.80
# 2                 1          342  47.574251 -122.407051     148.80
# 3                 2          342  47.574177 -122.407057     149.50
# 4                 2          342  47.574177 -122.407057     149.50
# ...             ...          ...        ...         ...        ...
# 391305       153210        66313  47.437303 -122.243141      24.02
# 391306       153210        66313  47.437303 -122.243141      24.02
# 391307       153211        66313  47.437099 -122.242644      25.40
# 391308       153211        66313  47.437099 -122.242644      25.40
# 391309       153211        66313  47.437099 -122.242644      25.40
#
#         Sampling Depth  Sampling Elevation                   USCS
# 0             0.600000          148.200000                   Fill
# 1             1.950000          146.850000                     ML
# 2             5.350000          143.450000                     ML
# 3             0.400000          149.100000  Topsoil or vegetation
# 4             1.650000          147.850000                     SM
# ...                ...                 ...                    ...
# 391305       22.666667            1.353333                     SM
# 391306       26.333333           -2.313333                     SM
# 391307        4.000000           21.400000                     SM
# 391308       13.000000           12.400000                     SM
# 391309       22.000000            3.400000                     SM
#
# [391310 rows x 8 columns]
